# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

from collections import deque

from ignite.engine import Engine, Events
from torch.utils.tensorboard import SummaryWriter
import datetime

from unityagents import UnityEnvironment

# %%
from dqn_per_dueling_agent import Agent

seed = 0
timesteps = list(range(10000))

# env = gym.make('LunarLander-v2')
# env.seed(seed)
env = UnityEnvironment(file_name="../Banana_Windows_x86_64/Banana.exe", no_graphics=True)
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

action_size = brain.vector_action_space_size
env_info = env.reset(train_mode=True)[brain_name]
state_size = len(env_info.vector_observations[0])

torch.manual_seed(seed)

eps_start = 1.
eps_end = 0.01
eps_decay = 0.9  # 309 ep # 0.95 prev, 322

now = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# writer = SummaryWriter("logs/unity-dueling/{}".format(now))

agent = Agent(state_size=state_size, action_size=action_size, seed=0) #, writer=writer)

scores = []
mean_scores = [] # for logging porpoises
# Out:
# cuda
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
EPISODE_STARTED = Events.EPOCH_STARTED
EPISODE_COMPLETED = Events.EPOCH_COMPLETED

def run_single_timestep(engine, timestep):
    eps = engine.state.eps
    state = engine.state.current_state
    #  (np.int32 because https://github.com/xkiwilabs/DQN-using-PyTorch-and-ML-Agents/issues/2)
    action = agent.act(state, eps).astype(np.int32)
    
#     next_state, reward, done, _ = env.step(action)
    env_info = env.step(action)[brain_name]
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]
    
    agent.step(state, action, reward, next_state, done)
    
    engine.state.current_state = next_state
    engine.state.score += reward
    
    if done:
        engine.terminate_epoch()
        engine.state.timestep = timestep

trainer = Engine(run_single_timestep)

@trainer.on(Events.STARTED)
def initialize(engine):
    # lists containing scores from each episode
    engine.state.scores = []                        
    engine.state.scores_window = deque(maxlen=100)
    engine.state.eps = eps_start


@trainer.on(EPISODE_STARTED)
def reset_environment_state(engine):
#     engine.state.current_state = env.reset()
    env_info = env.reset(train_mode=False)[brain_name]
    engine.state.current_state = env_info.vector_observations[0]
    engine.state.score = 0

@trainer.on(EPISODE_COMPLETED)
def update_model(engine):
    engine.state.eps = max(eps_end, eps_decay*engine.state.eps) # decrease epsilon
    
    score = engine.state.score
    engine.state.scores.append(score)
    engine.state.scores_window.append(score)

    scores.append(score)
    mean_scores.append(np.mean(engine.state.scores_window))
    
# @trainer.on(EPISODE_COMPLETED(every=10))
# def log_episode_to_tensorboard(engine):
#     i = engine.state.epoch
# #     writer.add_scalar('running reward', engine.state.running_reward, i_episode)
#     writer.add_scalar('Average episode score', np.mean(engine.state.scores_window), i)
#     writer.add_scalar('Average environment score', np.mean(engine.state.scores), i)

@trainer.on(EPISODE_COMPLETED)
def should_finish_training(engine):
    if np.mean(engine.state.scores_window)>=13.0:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(engine.state.epoch, np.mean(engine.state.scores_window)))
        torch.save(agent.qnetwork_local.state_dict(), 'checkpoint-per.pth')
        np.save('mean_scores.npy', np.array(mean_scores))
        np.save('scores.npy', np.array(scores))
        engine.should_terminate = True

# %%
trainer.run(timesteps, max_epochs=2000)
# Out:
# INFO:ignite.engine.engine.Engine:Engine run starting with max_epochs=2000.
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[1] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[2] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[3] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[4] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[5] Complete. Time taken: 00:00:34
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[6] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[7] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[8] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[9] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[10] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[11] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[12] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[13] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[14] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[15] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[16] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[17] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[18] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[19] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[20] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[21] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[22] Complete. Time taken: 00:00:37
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[23] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[24] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[25] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[26] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[27] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[28] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[29] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[30] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[31] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[32] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[33] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[34] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[35] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[36] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[37] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[38] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[39] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[40] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[41] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[42] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[43] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[44] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[45] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[46] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[47] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[48] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[49] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[50] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[51] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[52] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[53] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[54] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[55] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[56] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[57] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[58] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[59] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[60] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[61] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[62] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[63] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[64] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[65] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[66] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[67] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[68] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[69] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[70] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[71] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[72] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[73] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[74] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[75] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[76] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[77] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[78] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[79] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[80] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[81] Complete. Time taken: 00:00:32
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[82] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[83] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[84] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[85] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[86] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[87] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[88] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[89] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[90] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[91] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[92] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[93] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[94] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[95] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[96] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[97] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[98] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[99] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[100] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[101] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[102] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[103] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[104] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[105] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[106] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[107] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[108] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[109] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[110] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[111] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[112] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[113] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[114] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[115] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[116] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[117] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[118] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[119] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[120] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[121] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[122] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[123] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[124] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[125] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[126] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[127] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[128] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[129] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[130] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[131] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[132] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[133] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[134] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[135] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[136] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[137] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[138] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[139] Complete. Time taken: 00:00:32
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[140] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[141] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[142] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[143] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[144] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[145] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[146] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[147] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[148] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[149] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[150] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[151] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[152] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[153] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[154] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[155] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[156] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[157] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[158] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[159] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[160] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[161] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[162] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[163] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[164] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[165] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[166] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[167] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[168] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[169] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[170] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[171] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[172] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[173] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[174] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[175] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[176] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[177] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[178] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[179] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[180] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[181] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[182] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[183] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[184] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[185] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[186] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[187] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[188] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[189] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[190] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[191] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[192] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[193] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[194] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[195] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[196] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[197] Complete. Time taken: 00:00:32
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[198] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[199] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[200] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[201] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[202] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[203] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[204] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[205] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[206] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[207] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[208] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[209] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[210] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[211] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[212] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[213] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[214] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[215] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[216] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[217] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[218] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[219] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[220] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[221] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[222] Complete. Time taken: 00:00:31
# ...
# INFO:ignite.engine.engine.Engine:Epoch[238] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[239] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[240] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[241] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[242] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[243] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[244] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[245] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[246] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[247] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[248] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[249] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[250] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[251] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[252] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[253] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[254] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[255] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[256] Complete. Time taken: 00:00:32
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[257] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[258] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[259] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[260] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[261] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[262] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[263] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[264] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[265] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[266] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[267] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[268] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[269] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[270] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[271] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[272] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[273] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[274] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[275] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[276] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[277] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[278] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[279] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[280] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[281] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[282] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[283] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[284] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[285] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[286] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[287] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[288] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[289] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[290] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[291] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[292] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[293] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[294] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[295] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[296] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[297] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[298] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[299] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[300] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[301] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[302] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[303] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[304] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[305] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[306] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[307] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[308] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Terminate current epoch is signaled. Current epoch iteration will stop after current iteration is finished.
# INFO:ignite.engine.engine.Engine:Epoch[309] Complete. Time taken: 00:00:31
# INFO:ignite.engine.engine.Engine:Engine run complete. Time taken: 02:41:04
# Environment solved in 309 episodes!	Average Score: 13.02
# State:
# 	iteration: 92700
# 	epoch: 309
# 	epoch_length: 10000
# 	max_epochs: 2000
# 	output: <class 'NoneType'>
# 	batch: 299
# 	metrics: <class 'dict'>
# 	dataloader: <class 'list'>
# 	seed: <class 'NoneType'>
# 	times: <class 'dict'>
# 	scores: <class 'list'>
# 	scores_window: <class 'collections.deque'>
# 	eps: 0.01
# 	current_state: <class 'numpy.ndarray'>
# 	score: 18.0
# 	timestep: 299
